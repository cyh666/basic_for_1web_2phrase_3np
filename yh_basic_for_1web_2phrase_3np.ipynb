# %%
from urllib.parse import urlparse

url = 'https://www.most.gov.tw/folksonomy/list?menu_id=ba3d22f3-96fd-4adf-a078-91a05b8f0166&filter_uid=none&listKeyword=&pageNum=4&pageSize=18&view_mode=listView&subSite=main&l=ch&tagUid='

uc = urlparse(url)
print("NetLoc:", uc.netloc)
print("Path:", uc.path)

q_cmds = uc.query.split('&')
print("Query Commands:")
for cmd in q_cmds:
    print(cmd)
# Out:
# NetLoc: www.most.gov.tw
# Path: /folksonomy/list
# Query Commands:
# menu_id=ba3d22f3-96fd-4adf-a078-91a05b8f0166
# filter_uid=none
# listKeyword=
# pageNum=4
# pageSize=18
# view_mode=listView
# subSite=main
# l=ch
# tagUid=

# %%
phrase = 'Daniel Wang'
print (phrase)
print (len(phrase))
print (phrase.upper())
print (phrase.lower())
print (phrase[1])
print (phrase.index('D'))
print (phrase.replace('Daniel','Wang'))
# Out:
# Daniel Wang
# 11
# DANIEL WANG
# daniel wang
# a
# 0
# Wang Wang

# %%
import numpy as np
import matplotlib.pyplot as pt
x = np.arange(0,360)
y1= np.sin(x*np.pi/180)
y2= np.cos(x*np.pi/180)
y3= np.tan(x*np.pi/180)
# y4= np.csc(x*np.pi/180)
# y5= np.sec(x*np.pi/180)
# y6= np.cot(x*np.pi/180)
pt.plot(x,y1,color="blue")
pt.plot(x,y2,color="red")
pt.plot(x,y3,color="green")
# pt.plot(x,y4,color="gray")
# pt.plot(x,y5,color="red")
# pt.plot(x,y6,color="green")
pt.xlim(0,360)
pt.ylim(-11,11)
pt.show()
